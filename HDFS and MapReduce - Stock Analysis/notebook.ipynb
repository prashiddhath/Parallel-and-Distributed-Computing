# %% [markdown]
# Install yfinance

# %%
! pip install yfinance

# %% [markdown]
# Download stock data

# %%
import yfinance as yf
data = yf.download("AAPL IBM", start="2009-01-01", end="2019-12-31")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %% [markdown]
# Check what is in the data

# %%
data['Open']
# Out:
#                  AAPL         IBM
# Date
# 2009-01-02   3.067143   83.889999
# 2009-01-05   3.327500   86.419998
# 2009-01-06   3.426786   87.110001
# 2009-01-07   3.278929   87.830002
# 2009-01-08   3.229643   87.809998
# ...               ...         ...
# 2019-12-23  70.132500  135.779999
# 2019-12-24  71.172501  135.610001
# 2019-12-26  71.205002  134.979996
# 2019-12-27  72.779999  135.000000
# 2019-12-30  72.364998  135.199997
#
# [2767 rows x 2 columns]

# %% [markdown]
# Start the Hadoop cluster

# %%
# %%bash
# $HADOOP_HOME/sbin/start-dfs.sh
# $HADOOP_HOME/sbin/start-yarn.sh
# Out:
# Starting namenodes on [localhost]
# Starting datanodes
# Starting secondary namenodes [p-d412799a-8ad0-4b98-adca-7b7c79c259ea]
# Starting resourcemanager
# Starting nodemanagers

# %% [markdown]
# Upload the finance data set to HDFS

# %%
from hdfs3 import HDFileSystem
hdfs = HDFileSystem(host='localhost', port=9000)
with hdfs.open('AAPL_IBM_open.csv', 'wb') as f:
    data['Open'].to_csv(f,header=True)

# %% [markdown]
# Check that the data set arrived at its final location

# %%
hdfs.ls('.')

# %% [markdown]
# Implementation of MapReduce job
# (Here, the task was to give the maximum opening value per year for two companies in the fourth quarter of the year.)

# %%
# %%file stock_analysis.py

from mrjob.job import MRJob

import re
import sys

class StockAnalysis(MRJob):

   def mapper(self, key, value):
      date, apple_open, ibm_open = value.split(',')
      #print(value, file=sys.stderr)
      year = date[:4]
      month = date[5:7]
      if (month=='10' or month=='11' or month=='12'):
         apple_key = 'apple_%s' % year
         ibm_key = 'ibm_%s' % year
         yield(apple_key, float(apple_open))
         yield(ibm_key, float(ibm_open))
      
   def reducer(self, key, values):
      yield(key, max(values))

if __name__ == '__main__':
   StockAnalysis.run()
# Out:
# Overwriting stock_analysis.py

# %% [markdown]
# Run MapReduce analysis job on cluster

# %%
# !python stock_analysis.py -r hadoop hdfs:///user/root/AAPL_IBM_open.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /root/hadoop-3.3.1/bin...
# Found hadoop binary: /root/hadoop-3.3.1/bin/hadoop
# Using Hadoop version 3.3.1
# Looking for Hadoop streaming jar in /root/hadoop-3.3.1...
# Found Hadoop streaming jar: /root/hadoop-3.3.1/share/hadoop/tools/lib/hadoop-streaming-3.3.1.jar
# Creating temp directory /tmp/stock_analysis.root.20211104.143802.189837
# uploading working dir files to hdfs:///user/root/tmp/mrjob/stock_analysis.root.20211104.143802.189837/files/wd...
# Copying other local files to hdfs:///user/root/tmp/mrjob/stock_analysis.root.20211104.143802.189837/files/
# Running step 1 of 1...
#   packageJobJar: [/tmp/hadoop-unjar14527474772028646990/] [] /tmp/streamjob7883098047006751013.jar tmpDir=null
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Connecting to ResourceManager at /0.0.0.0:8032
#   Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1636035523910_0002
#   Total input files to process : 1
#   number of splits:2
#   Submitting tokens for job: job_1636035523910_0002
#   Executing with tokens: []
#   resource-types.xml not found
#   Unable to find 'resource-types.xml'.
#   Submitted application application_1636035523910_0002
#   The url to track the job: http://p-d412799a-8ad0-4b98-adca-7b7c79c259ea:8088/proxy/application_1636035523910_0002/
#   Running job: job_1636035523910_0002
#   Job job_1636035523910_0002 running in uber mode : false
#    map 0% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 100%
#   Job job_1636035523910_0002 completed successfully
#   Output directory: hdfs:///user/root/tmp/mrjob/stock_analysis.root.20211104.143802.189837/output
# Counters: 55
# 	File Input Format Counters
# 		Bytes Read=129826
# 	File Output Format Counters
# 		Bytes Written=660
# 	File System Counters
# 		FILE: Number of bytes read=44258
# 		FILE: Number of bytes written=919374
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=130028
# 		HDFS: Number of bytes read erasure-coded=0
# 		HDFS: Number of bytes written=660
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=11
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=2
# 		Killed map tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=1
# 		Total megabyte-milliseconds taken by all map tasks=24713216
# 		Total megabyte-milliseconds taken by all reduce tasks=6254592
# 		Total time spent by all map tasks (ms)=24134
# 		Total time spent by all maps in occupied slots (ms)=24134
# 		Total time spent by all reduce tasks (ms)=6108
# 		Total time spent by all reduces in occupied slots (ms)=6108
# 		Total vcore-milliseconds taken by all map tasks=24134
# 		Total vcore-milliseconds taken by all reduce tasks=6108
# 	Map-Reduce Framework
# 		CPU time spent (ms)=3040
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=267
# 		Input split bytes=202
# 		Map input records=2768
# 		Map output bytes=41464
# 		Map output materialized bytes=44264
# 		Map output records=1394
# 		Merged Map outputs=2
# 		Peak Map Physical memory (bytes)=272519168
# 		Peak Map Virtual memory (bytes)=2727260160
# 		Peak Reduce Physical memory (bytes)=201547776
# 		Peak Reduce Virtual memory (bytes)=2727710720
# 		Physical memory (bytes) snapshot=735678464
# 		Reduce input groups=22
# 		Reduce input records=1394
# 		Reduce output records=22
# 		Reduce shuffle bytes=44264
# 		Shuffled Maps =2
# 		Spilled Records=2788
# 		Total committed heap usage (bytes)=657457152
# 		Virtual memory (bytes) snapshot=8175800320
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# job output is in hdfs:///user/root/tmp/mrjob/stock_analysis.root.20211104.143802.189837/output
# Streaming final output from hdfs:///user/root/tmp/mrjob/stock_analysis.root.20211104.143802.189837/output...
# "apple_2009"	7.611785888671875
# "apple_2010"	11.650713920593262
# "apple_2011"	15.062856674194336
# "apple_2012"	23.97321319580078
# "apple_2013"	20.451786041259766
# "apple_2014"	29.8174991607666
# "apple_2015"	30.782499313354492
# "apple_2016"	29.545000076293945
# "apple_2017"	43.77750015258789
# "apple_2018"	57.69499969482422
# "apple_2019"	72.77999877929688
# "ibm_2009"	132.41000366210938
# "ibm_2010"	146.72999572753906
# "ibm_2011"	193.63999938964844
# "ibm_2012"	211.14999389648438
# "ibm_2013"	186.49000549316406
# "ibm_2014"	189.91000366210938
# "ibm_2015"	152.4600067138672
# "ibm_2016"	168.97000122070312
# "ibm_2017"	162.0500030517578
# "ibm_2018"	154.0
# "ibm_2019"	145.58999633789062
# Removing HDFS temp directory hdfs:///user/root/tmp/mrjob/stock_analysis.root.20211104.143802.189837...
# Removing temp directory /tmp/stock_analysis.root.20211104.143802.189837...

# %% [markdown]
# Shutdown Hadoop cluster

# %%
# %%bash
# $HADOOP_HOME/sbin/stop-yarn.sh
# $HADOOP_HOME/sbin/stop-dfs.sh

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d412799a-8ad0-4b98-adca-7b7c79c259ea' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
